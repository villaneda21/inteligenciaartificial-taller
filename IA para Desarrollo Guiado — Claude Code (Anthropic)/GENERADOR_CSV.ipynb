# %%
# Ejecuta esto una sola vez para crear el archivo de prueba
csv_content = """id,monto
TX-001,1500.50
TX-002,300.00
TX-003,50.00
TX-004,1200.00
TX-005,450.75"""

with open("datos.csv", "w") as f:
    f.write(csv_content)
print("Archivo datos.csv creado.")
# Out:
# Archivo datos.csv creado.
